# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, BatchNormalization,
                                     Activation, Dropout, Flatten, Dense, GlobalAveragePooling2D)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

# ----------------------------
# 1. Model Architecture: UniScriptNet
# ----------------------------

def build_uniscriptnet(input_shape=(32, 32, 1), num_classes = 84):
    model = Sequential([
        InputLayer(input_shape=input_shape),
        
        # Block 1
        Conv2D(32, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.25),

        # Block 2
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.25),

        # Block 3
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.25),

        # Fully Connected
        Flatten(),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

print("Model Designed successfully")
# Out:
# 2025-06-09 12:24:15.288906: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749471855.471869      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749471855.537141      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Model Designed successfully

# %%
# ----------------------------
# 2. Data Loading: BanglaLekha-Isolated
# ----------------------------
# Replace this with your full Google Drive path if needed
dataset_path = "/kaggle/input/bangla-lekha-isolated-dataset/BanglaLekha-Isolated/Images"

image_size = (32, 32)
input_shape = (32, 32, 1)
batch_size = 64
epochs = 80
num_classes = 84  # Update if using fewer classes

# ImageDataGenerator with augmentation for training and only rescaling for validation
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=5,              # Safe for all
    width_shift_range=0.05,         
    height_shift_range=0.05,
    zoom_range=0.1,
    shear_range=0.05,
    horizontal_flip=False,          # Do not flip
    validation_split=0.2
)


train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=image_size,
    color_mode='grayscale',
    class_mode='categorical',
    batch_size=batch_size,
    subset='training',
    shuffle=True,
    seed=33
)

val_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=image_size,
    color_mode='grayscale',
    class_mode='categorical',
    batch_size=batch_size,
    subset='validation',
    shuffle=False,
    seed=33
)
# Out:
# Found 132914 images belonging to 84 classes.
# Found 33191 images belonging to 84 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, InputLayer


# ----------------------------
# 3. Compile Model
# ----------------------------
model = build_uniscriptnet(input_shape=input_shape, num_classes=num_classes)
model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# I0000 00:00:1749471951.471882      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1749471951.472547      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 84)                  │          21,588 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 640,724 (2.44 MB)
#  Trainable params: 639,764 (2.44 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# ----------------------------
# 4. Callbacks
# ----------------------------
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, verbose=1),
    EarlyStopping(monitor='val_accuracy', patience=8, min_delta=0.001, restore_best_weights=True),
    ModelCheckpoint("scriptnet_banglalekha_best.h5", monitor="val_accuracy", save_best_only=True, verbose=1)
]

epochs = 80

# ----------------------------
# 5. Train Model
# ----------------------------
steps_per_epoch = np.ceil(train_generator.samples / batch_size).astype(int)
validation_steps = np.ceil(val_generator.samples / batch_size).astype(int)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.4348 - loss: 2.2301
# Epoch 1: val_accuracy improved from -inf to 0.87894, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 617s 297ms/step - accuracy: 0.4349 - loss: 2.2298 - val_accuracy: 0.8789 - val_loss: 0.4177 - learning_rate: 0.0010
# Epoch 2/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.7460 - loss: 0.9106
# Epoch 2: val_accuracy improved from 0.87894 to 0.90958, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 352s 169ms/step - accuracy: 0.7460 - loss: 0.9106 - val_accuracy: 0.9096 - val_loss: 0.3127 - learning_rate: 0.0010
# Epoch 3/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7869 - loss: 0.7698
# Epoch 3: val_accuracy improved from 0.90958 to 0.92408, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 329s 159ms/step - accuracy: 0.7869 - loss: 0.7698 - val_accuracy: 0.9241 - val_loss: 0.2631 - learning_rate: 0.0010
# Epoch 4/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8037 - loss: 0.7075
# Epoch 4: val_accuracy improved from 0.92408 to 0.93167, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 347s 167ms/step - accuracy: 0.8037 - loss: 0.7075 - val_accuracy: 0.9317 - val_loss: 0.2414 - learning_rate: 0.0010
# Epoch 5/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8132 - loss: 0.6595
# Epoch 5: val_accuracy improved from 0.93167 to 0.93507, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 344s 166ms/step - accuracy: 0.8132 - loss: 0.6595 - val_accuracy: 0.9351 - val_loss: 0.2262 - learning_rate: 0.0010
# Epoch 6/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8237 - loss: 0.6272
# Epoch 6: val_accuracy improved from 0.93507 to 0.93739, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 349s 168ms/step - accuracy: 0.8237 - loss: 0.6272 - val_accuracy: 0.9374 - val_loss: 0.2201 - learning_rate: 0.0010
# Epoch 7/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8337 - loss: 0.5908
# Epoch 8: val_accuracy improved from 0.94218 to 0.94381, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 370s 178ms/step - accuracy: 0.8337 - loss: 0.5908 - val_accuracy: 0.9438 - val_loss: 0.1985 - learning_rate: 0.0010
# Epoch 9/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8369 - loss: 0.5749
# Epoch 9: val_accuracy improved from 0.94381 to 0.94408, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 365s 176ms/step - accuracy: 0.8369 - loss: 0.5749 - val_accuracy: 0.9441 - val_loss: 0.1999 - learning_rate: 0.0010
# Epoch 10/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8438 - loss: 0.5475
# Epoch 10: val_accuracy did not improve from 0.94408
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 363s 175ms/step - accuracy: 0.8438 - loss: 0.5475 - val_accuracy: 0.9424 - val_loss: 0.1965 - learning_rate: 0.0010
# Epoch 11/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8468 - loss: 0.5373
# Epoch 11: val_accuracy did not improve from 0.94408
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 346s 166ms/step - accuracy: 0.8468 - loss: 0.5373 - val_accuracy: 0.9433 - val_loss: 0.1981 - learning_rate: 0.0010
# Epoch 12/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8490 - loss: 0.5312
# Epoch 12: val_accuracy improved from 0.94408 to 0.94604, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 353s 170ms/step - accuracy: 0.8490 - loss: 0.5312 - val_accuracy: 0.9460 - val_loss: 0.1897 - learning_rate: 0.0010
# Epoch 13/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8515 - loss: 0.5222
# Epoch 13: val_accuracy improved from 0.94604 to 0.94932, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 375s 181ms/step - accuracy: 0.8515 - loss: 0.5222 - val_accuracy: 0.9493 - val_loss: 0.1801 - learning_rate: 0.0010
# Epoch 14/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8520 - loss: 0.5167
# Epoch 14: val_accuracy did not improve from 0.94932
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 403s 194ms/step - accuracy: 0.8520 - loss: 0.5167 - val_accuracy: 0.9465 - val_loss: 0.1877 - learning_rate: 0.0010
# Epoch 15/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8540 - loss: 0.5095
# Epoch 15: val_accuracy did not improve from 0.94932
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 370s 178ms/step - accuracy: 0.8540 - loss: 0.5095 - val_accuracy: 0.9479 - val_loss: 0.1835 - learning_rate: 0.0010
# Epoch 16/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8571 - loss: 0.5020
# Epoch 16: val_accuracy improved from 0.94932 to 0.94972, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 401s 193ms/step - accuracy: 0.8571 - loss: 0.5020 - val_accuracy: 0.9497 - val_loss: 0.1769 - learning_rate: 0.0010
# Epoch 17/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8624 - loss: 0.4866
# Epoch 17: val_accuracy improved from 0.94972 to 0.95080, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 496s 239ms/step - accuracy: 0.8624 - loss: 0.4866 - val_accuracy: 0.9508 - val_loss: 0.1743 - learning_rate: 0.0010
# Epoch 18/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8591 - loss: 0.4907
# Epoch 18: val_accuracy improved from 0.95080 to 0.95158, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 443s 213ms/step - accuracy: 0.8591 - loss: 0.4907 - val_accuracy: 0.9516 - val_loss: 0.1708 - learning_rate: 0.0010
# Epoch 19/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8618 - loss: 0.4874
# Epoch 19: val_accuracy improved from 0.95158 to 0.95291, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 414s 200ms/step - accuracy: 0.8618 - loss: 0.4874 - val_accuracy: 0.9529 - val_loss: 0.1711 - learning_rate: 0.0010
# Epoch 20/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8662 - loss: 0.4695
# Epoch 20: val_accuracy did not improve from 0.95291
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 441s 212ms/step - accuracy: 0.8662 - loss: 0.4695 - val_accuracy: 0.9479 - val_loss: 0.1862 - learning_rate: 0.0010
# Epoch 21/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8633 - loss: 0.4750
# Epoch 21: val_accuracy did not improve from 0.95291
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 421s 203ms/step - accuracy: 0.8633 - loss: 0.4750 - val_accuracy: 0.9516 - val_loss: 0.1733 - learning_rate: 0.0010
# Epoch 22/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8651 - loss: 0.4701
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 22: val_accuracy did not improve from 0.95291
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 422s 203ms/step - accuracy: 0.8651 - loss: 0.4701 - val_accuracy: 0.9512 - val_loss: 0.1752 - learning_rate: 0.0010
# Epoch 23/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8731 - loss: 0.4490
# Epoch 23: val_accuracy improved from 0.95291 to 0.95472, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 455s 219ms/step - accuracy: 0.8731 - loss: 0.4490 - val_accuracy: 0.9547 - val_loss: 0.1617 - learning_rate: 5.0000e-04
# Epoch 24/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8731 - loss: 0.4459
# Epoch 24: val_accuracy did not improve from 0.95472
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 461s 222ms/step - accuracy: 0.8731 - loss: 0.4459 - val_accuracy: 0.9544 - val_loss: 0.1637 - learning_rate: 5.0000e-04
# Epoch 25/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8745 - loss: 0.4406
# Epoch 25: val_accuracy did not improve from 0.95472
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 472s 227ms/step - accuracy: 0.8745 - loss: 0.4406 - val_accuracy: 0.9541 - val_loss: 0.1612 - learning_rate: 5.0000e-04
# Epoch 26/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8750 - loss: 0.4352
# Epoch 26: val_accuracy improved from 0.95472 to 0.95508, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 447s 215ms/step - accuracy: 0.8750 - loss: 0.4352 - val_accuracy: 0.9551 - val_loss: 0.1588 - learning_rate: 5.0000e-04
# Epoch 27/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8764 - loss: 0.4294
# Epoch 27: val_accuracy improved from 0.95508 to 0.95511, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 448s 216ms/step - accuracy: 0.8764 - loss: 0.4294 - val_accuracy: 0.9551 - val_loss: 0.1610 - learning_rate: 5.0000e-04
# Epoch 28/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8779 - loss: 0.4221
# Epoch 28: val_accuracy improved from 0.95511 to 0.95544, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 429s 207ms/step - accuracy: 0.8779 - loss: 0.4221 - val_accuracy: 0.9554 - val_loss: 0.1609 - learning_rate: 5.0000e-04
# Epoch 29/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8770 - loss: 0.4271
# Epoch 29: val_accuracy improved from 0.95544 to 0.95631, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 447s 215ms/step - accuracy: 0.8770 - loss: 0.4271 - val_accuracy: 0.9563 - val_loss: 0.1587 - learning_rate: 5.0000e-04
# Epoch 30/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8780 - loss: 0.4221
# Epoch 30: val_accuracy did not improve from 0.95631
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 441s 212ms/step - accuracy: 0.8780 - loss: 0.4221 - val_accuracy: 0.9553 - val_loss: 0.1570 - learning_rate: 5.0000e-04
# Epoch 31/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8773 - loss: 0.4260
# Epoch 31: val_accuracy did not improve from 0.95631
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 427s 206ms/step - accuracy: 0.8773 - loss: 0.4260 - val_accuracy: 0.9547 - val_loss: 0.1606 - learning_rate: 5.0000e-04
# Epoch 32/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8787 - loss: 0.4177
# Epoch 32: val_accuracy did not improve from 0.95631
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 442s 213ms/step - accuracy: 0.8787 - loss: 0.4177 - val_accuracy: 0.9562 - val_loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 33/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8794 - loss: 0.4197
# Epoch 33: val_accuracy did not improve from 0.95631
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 410s 198ms/step - accuracy: 0.8794 - loss: 0.4197 - val_accuracy: 0.9563 - val_loss: 0.1567 - learning_rate: 5.0000e-04
# Epoch 34/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8803 - loss: 0.4149
# Epoch 34: val_accuracy did not improve from 0.95631
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 398s 192ms/step - accuracy: 0.8803 - loss: 0.4149 - val_accuracy: 0.9556 - val_loss: 0.1595 - learning_rate: 5.0000e-04
# Epoch 35/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8803 - loss: 0.4119
# Epoch 35: val_accuracy did not improve from 0.95631
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 452s 218ms/step - accuracy: 0.8803 - loss: 0.4119 - val_accuracy: 0.9561 - val_loss: 0.1572 - learning_rate: 5.0000e-04
# Epoch 36/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8815 - loss: 0.4090
# Epoch 36: val_accuracy did not improve from 0.95631
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 436s 210ms/step - accuracy: 0.8815 - loss: 0.4090 - val_accuracy: 0.9547 - val_loss: 0.1571 - learning_rate: 5.0000e-04
# Epoch 37/80
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8812 - loss: 0.4105
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 37: val_accuracy improved from 0.95631 to 0.95667, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 439s 211ms/step - accuracy: 0.8812 - loss: 0.4105 - val_accuracy: 0.9567 - val_loss: 0.1588 - learning_rate: 5.0000e-04

# %%
import matplotlib.pyplot as plt

# Plot Accuracy
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Predict labels
y_pred_probs = model.predict(val_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = val_generator.classes

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
labels = list(val_generator.class_indices.keys())

# Create large figure
fig, ax = plt.subplots(figsize=(20, 20))  # Adjust size as needed

# Display Confusion Matrix with custom axis
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap='Blues', ax=ax, xticks_rotation=90)

# Improve font sizes for visibility
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Confusion Matrix", fontsize=20)
plt.xlabel("Predicted Label", fontsize=16)
plt.ylabel("True Label", fontsize=16)
plt.grid(False)

plt.show()
# Out:
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 90s 173ms/step

# %%
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

# Predict and true labels (already obtained previously)
y_pred_probs = model.predict(val_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = val_generator.classes
class_names = list(val_generator.class_indices.keys())

# Print classification report
report = classification_report(y_true, y_pred, target_names=class_names, digits=4)
print("📋 Classification Report:\n")
print(report)

# Extract and print macro, weighted scores
precision_macro = precision_score(y_true, y_pred, average='macro')
recall_macro = recall_score(y_true, y_pred, average='macro')
f1_macro = f1_score(y_true, y_pred, average='macro')

precision_weighted = precision_score(y_true, y_pred, average='weighted')
recall_weighted = recall_score(y_true, y_pred, average='weighted')
f1_weighted = f1_score(y_true, y_pred, average='weighted')

print("🔢 Macro Scores")
print(f"Precision (Macro): {precision_macro:.4f}")
print(f"Recall (Macro):    {recall_macro:.4f}")
print(f"F1-score (Macro):  {f1_macro:.4f}")

print("\n🔢 Weighted Scores")
print(f"Precision (Weighted): {precision_weighted:.4f}")
print(f"Recall (Weighted):    {recall_weighted:.4f}")
print(f"F1-score (Weighted):  {f1_weighted:.4f}")
# Out:
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 40s 76ms/step
# 📋 Classification Report:
#
#               precision    recall  f1-score   support
#
#           01     0.9509    0.9797    0.9651       395
#           02     0.9551    0.9672    0.9611       396
#           03     0.9796    0.9722    0.9759       395
#           04     0.9772    0.9747    0.9760       396
#           05     0.9570    0.9545    0.9558       396
#           06     0.9693    0.9571    0.9632       396
#           07     0.9698    0.9797    0.9747       394
#           08     0.9872    0.9748    0.9810       397
#           09     0.9898    0.9823    0.9861       396
#           10     0.9563    0.9394    0.9478       396
#           11     0.9750    0.9848    0.9799       396
#           12     0.9535    0.9848    0.9689       396
#           13     0.9730    0.9160    0.9436       393
#           14     0.9715    0.9470    0.9591       396
#           15     0.9242    0.9266    0.9254       395
#           16     0.9769    0.9621    0.9695       396
#           17     0.9439    0.9773    0.9603       396
#           18     0.9919    0.9293    0.9596       396
#           19     0.9875    0.9949    0.9912       396
#           20     0.9610    0.9949    0.9777       396
#           21     0.9875    0.9950    0.9912       397
#           22     0.9898    0.9797    0.9847       395
#           23     0.9595    0.9768    0.9681       388
#           24     0.9171    0.9217    0.9194       396
#           25     0.9521    0.9570    0.9545       395
#           26     0.9249    0.9646    0.9444       396
#           27     0.9403    0.9570    0.9486       395
#           28     0.8826    0.9519    0.9160       395
#           29     0.9873    0.9823    0.9848       396
#           30     0.9895    0.9618    0.9755       393
#           31     0.9100    0.9444    0.9269       396
#           32     0.9440    0.9773    0.9604       397
#           33     0.9796    0.9722    0.9759       396
#           34     0.9657    0.9949    0.9801       396
#           35     0.9381    0.9192    0.9286       396
#           36     0.8726    0.9343    0.9024       396
#           37     0.9146    0.9169    0.9157       397
#           38     0.9798    0.9823    0.9811       396
#           39     0.9845    0.9669    0.9756       393
#           40     0.9421    0.9468    0.9444       395
#           41     0.9280    0.9492    0.9385       394
#           42     0.9421    0.9040    0.9227       396
#           43     0.9442    0.9848    0.9641       395
#           44     0.9898    0.9823    0.9861       396
#           45     0.9747    0.9822    0.9785       393
#           46     0.9795    0.9672    0.9733       396
#           47     0.9850    0.9924    0.9887       396
#           48     0.9974    0.9823    0.9898       396
#           49     0.9950    1.0000    0.9975       396
#           50     1.0000    0.9975    0.9987       396
#           51     0.9825    0.9899    0.9862       396
#           52     0.9848    0.9848    0.9848       396
#           53     0.9871    0.9795    0.9833       390
#           54     0.9548    0.9620    0.9584       395
#           55     0.9874    0.9899    0.9887       396
#           56     0.9770    0.9647    0.9708       397
#           57     0.9606    0.9848    0.9726       396
#           58     0.9898    0.9974    0.9936       391
#           59     0.9899    0.9924    0.9912       396
#           60     0.9740    0.9517    0.9627       393
#           61     0.8111    0.8131    0.8121       396
#           62     0.9703    0.9899    0.9800       396
#           63     0.9783    0.9231    0.9499       390
#           64     0.8832    0.9144    0.8985       397
#           65     0.9304    0.8456    0.8859       395
#           66     0.9638    0.9443    0.9540       395
#           67     0.9422    0.9874    0.9642       396
#           68     0.9922    0.9596    0.9756       396
#           69     0.9795    0.9647    0.9721       397
#           70     0.9578    0.9747    0.9662       396
#           71     0.8729    0.7863    0.8273       393
#           72     0.8104    0.7939    0.8021       393
#           73     0.9583    0.9849    0.9714       397
#           74     0.9698    0.9722    0.9710       396
#           75     0.9385    0.8931    0.9153       393
#           76     0.9924    0.9848    0.9886       396
#           77     0.9646    0.9124    0.9377       388
#           78     0.9675    0.9773    0.9724       396
#           79     0.9719    0.9646    0.9682       395
#           80     0.8135    0.9141    0.8609       396
#           81     0.9872    0.9772    0.9822       395
#           82     0.9949    0.9873    0.9911       395
#           83     0.9424    0.9137    0.9278       394
#           84     0.9738    0.9440    0.9587       393
#
#     accuracy                         0.9568     33191
#    macro avg     0.9572    0.9567    0.9567     33191
# weighted avg     0.9572    0.9568    0.9567     33191
#
# 🔢 Macro Scores
# Precision (Macro): 0.9572
# Recall (Macro):    0.9567
# F1-score (Macro):  0.9567
#
# 🔢 Weighted Scores
# Precision (Weighted): 0.9572
# Recall (Weighted):    0.9568
# F1-score (Weighted):  0.9567
