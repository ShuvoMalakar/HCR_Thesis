# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, BatchNormalization,
                                     Activation, Dropout, Flatten, Dense, GlobalAveragePooling2D)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

# ----------------------------
# 1. Model Architecture: UniScriptNet
# ----------------------------

def build_uniscriptnet(input_shape=(32, 32, 1), num_classes = 10):
    model = Sequential([
        InputLayer(input_shape=input_shape),
        
        # Block 1
        Conv2D(32, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.25),

        # Block 2
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.25),

        # Block 3
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.25),

        # Fully Connected
        Flatten(),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

print("Model Designed successfully")
# Out:
# Model Designed successfully

# %%
# ----------------------------
# 2. Data Loading: BanglaLekha-Isolated
# ----------------------------
# Replace this with your full Google Drive path if needed
dataset_path = "/kaggle/input/bangla-lekha-isolated-dataset/BanglaLekha-Isolated/Images-10classes"

image_size = (32, 32)
input_shape = (32, 32, 1)
batch_size = 64
epochs = 50
num_classes = 10  # Update if using fewer classes

# ImageDataGenerator with augmentation for training and only rescaling for validation
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=5,              # Safe for all
    width_shift_range=0.05,         
    height_shift_range=0.05,
    zoom_range=0.1,
    shear_range=0.05,
    horizontal_flip=False,          # Do not flip
    validation_split=0.2
)


train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=image_size,
    color_mode='grayscale',
    class_mode='categorical',
    batch_size=batch_size,
    subset='training',
    shuffle=True,
    seed=42
)

val_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=image_size,
    color_mode='grayscale',
    class_mode='categorical',
    batch_size=batch_size,
    subset='validation',
    shuffle=False,
    seed=42
)
# Out:
# Found 15844 images belonging to 10 classes.
# Found 3957 images belonging to 10 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, InputLayer


# ----------------------------
# 3. Compile Model
# ----------------------------
model = build_uniscriptnet(input_shape=input_shape, num_classes=num_classes)
model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 32, 32, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 621,706 (2.37 MB)
#  Trainable params: 620,746 (2.37 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# ----------------------------
# 4. Callbacks
# ----------------------------
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, verbose=1),
    EarlyStopping(monitor='val_accuracy', patience=8, min_delta=0.001, restore_best_weights=True),
    ModelCheckpoint("scriptnet_banglalekha_best.h5", monitor="val_accuracy", save_best_only=True, verbose=1)
]

epochs = 60

# ----------------------------
# 5. Train Model
# ----------------------------
steps_per_epoch = np.ceil(train_generator.samples / batch_size).astype(int)
validation_steps = np.ceil(val_generator.samples / batch_size).astype(int)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.5382 - loss: 1.4230
# Epoch 1: val_accuracy improved from -inf to 0.25499, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 99s 374ms/step - accuracy: 0.5387 - loss: 1.4212 - val_accuracy: 0.2550 - val_loss: 2.8043 - learning_rate: 0.0010
# Epoch 2/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8179 - loss: 0.5288
# Epoch 2: val_accuracy improved from 0.25499 to 0.87010, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 198ms/step - accuracy: 0.8179 - loss: 0.5287 - val_accuracy: 0.8701 - val_loss: 0.4387 - learning_rate: 0.0010
# Epoch 3/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8674 - loss: 0.3875
# Epoch 3: val_accuracy improved from 0.87010 to 0.94819, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 47s 191ms/step - accuracy: 0.8674 - loss: 0.3875 - val_accuracy: 0.9482 - val_loss: 0.1646 - learning_rate: 0.0010
# Epoch 4/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8822 - loss: 0.3336
# Epoch 4: val_accuracy improved from 0.94819 to 0.95855, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 196ms/step - accuracy: 0.8822 - loss: 0.3336 - val_accuracy: 0.9586 - val_loss: 0.1455 - learning_rate: 0.0010
# Epoch 5/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8964 - loss: 0.3030
# Epoch 5: val_accuracy did not improve from 0.95855
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 47s 191ms/step - accuracy: 0.8964 - loss: 0.3030 - val_accuracy: 0.9570 - val_loss: 0.1480 - learning_rate: 0.0010
# Epoch 6/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9052 - loss: 0.2746
# Epoch 6: val_accuracy did not improve from 0.95855
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 197ms/step - accuracy: 0.9052 - loss: 0.2746 - val_accuracy: 0.9538 - val_loss: 0.1421 - learning_rate: 0.0010
# Epoch 7/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9174 - loss: 0.2335
# Epoch 7: val_accuracy improved from 0.95855 to 0.96765, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 48s 192ms/step - accuracy: 0.9174 - loss: 0.2336 - val_accuracy: 0.9677 - val_loss: 0.1189 - learning_rate: 0.0010
# Epoch 8/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9251 - loss: 0.2320
# Epoch 8: val_accuracy improved from 0.96765 to 0.96942, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 48s 193ms/step - accuracy: 0.9251 - loss: 0.2320 - val_accuracy: 0.9694 - val_loss: 0.1056 - learning_rate: 0.0010
# Epoch 9/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9307 - loss: 0.2134
# Epoch 9: val_accuracy did not improve from 0.96942
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 48s 195ms/step - accuracy: 0.9307 - loss: 0.2134 - val_accuracy: 0.9684 - val_loss: 0.1101 - learning_rate: 0.0010
# Epoch 10/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9297 - loss: 0.2092
# Epoch 10: val_accuracy did not improve from 0.96942
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 196ms/step - accuracy: 0.9298 - loss: 0.2092 - val_accuracy: 0.9631 - val_loss: 0.1203 - learning_rate: 0.0010
# Epoch 11/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9339 - loss: 0.1992
# Epoch 11: val_accuracy improved from 0.96942 to 0.97170, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 48s 195ms/step - accuracy: 0.9339 - loss: 0.1992 - val_accuracy: 0.9717 - val_loss: 0.1010 - learning_rate: 0.0010
# Epoch 12/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9423 - loss: 0.1838
# Epoch 12: val_accuracy improved from 0.97170 to 0.97346, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 198ms/step - accuracy: 0.9423 - loss: 0.1838 - val_accuracy: 0.9735 - val_loss: 0.1023 - learning_rate: 0.0010
# Epoch 13/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9429 - loss: 0.1760
# Epoch 13: val_accuracy improved from 0.97346 to 0.97700, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 48s 195ms/step - accuracy: 0.9429 - loss: 0.1760 - val_accuracy: 0.9770 - val_loss: 0.0916 - learning_rate: 0.0010
# Epoch 14/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9434 - loss: 0.1763
# Epoch 14: val_accuracy did not improve from 0.97700
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 48s 192ms/step - accuracy: 0.9434 - loss: 0.1763 - val_accuracy: 0.9760 - val_loss: 0.0852 - learning_rate: 0.0010
# Epoch 15/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9453 - loss: 0.1605
# Epoch 15: val_accuracy improved from 0.97700 to 0.97776, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 47s 189ms/step - accuracy: 0.9453 - loss: 0.1605 - val_accuracy: 0.9778 - val_loss: 0.0914 - learning_rate: 0.0010
# Epoch 16/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9466 - loss: 0.1639
# Epoch 16: val_accuracy did not improve from 0.97776
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 48s 193ms/step - accuracy: 0.9466 - loss: 0.1639 - val_accuracy: 0.9757 - val_loss: 0.0940 - learning_rate: 0.0010
# Epoch 17/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9465 - loss: 0.1616
# Epoch 17: val_accuracy improved from 0.97776 to 0.97902, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 48s 193ms/step - accuracy: 0.9465 - loss: 0.1616 - val_accuracy: 0.9790 - val_loss: 0.0845 - learning_rate: 0.0010
# Epoch 18/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9567 - loss: 0.1317
# Epoch 21: val_accuracy did not improve from 0.97978
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 196ms/step - accuracy: 0.9567 - loss: 0.1317 - val_accuracy: 0.9762 - val_loss: 0.0873 - learning_rate: 0.0010
# Epoch 22/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9508 - loss: 0.1414
# Epoch 22: val_accuracy did not improve from 0.97978
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 198ms/step - accuracy: 0.9508 - loss: 0.1414 - val_accuracy: 0.9775 - val_loss: 0.0849 - learning_rate: 0.0010
# Epoch 23/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9539 - loss: 0.1396
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 23: val_accuracy did not improve from 0.97978
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 48s 194ms/step - accuracy: 0.9539 - loss: 0.1396 - val_accuracy: 0.9790 - val_loss: 0.0826 - learning_rate: 0.0010
# Epoch 24/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9593 - loss: 0.1265
# Epoch 24: val_accuracy improved from 0.97978 to 0.98130, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 197ms/step - accuracy: 0.9593 - loss: 0.1265 - val_accuracy: 0.9813 - val_loss: 0.0719 - learning_rate: 5.0000e-04
# Epoch 25/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9644 - loss: 0.1159
# Epoch 25: val_accuracy improved from 0.98130 to 0.98155, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 48s 192ms/step - accuracy: 0.9644 - loss: 0.1159 - val_accuracy: 0.9816 - val_loss: 0.0749 - learning_rate: 5.0000e-04
# Epoch 26/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9644 - loss: 0.1102
# Epoch 26: val_accuracy did not improve from 0.98155
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 48s 193ms/step - accuracy: 0.9644 - loss: 0.1102 - val_accuracy: 0.9813 - val_loss: 0.0789 - learning_rate: 5.0000e-04
# Epoch 27/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9644 - loss: 0.1102
# Epoch 27: val_accuracy did not improve from 0.98155
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 196ms/step - accuracy: 0.9643 - loss: 0.1102 - val_accuracy: 0.9816 - val_loss: 0.0715 - learning_rate: 5.0000e-04
# Epoch 28/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9658 - loss: 0.1072
# Epoch 28: val_accuracy did not improve from 0.98155
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 50s 200ms/step - accuracy: 0.9658 - loss: 0.1072 - val_accuracy: 0.9803 - val_loss: 0.0771 - learning_rate: 5.0000e-04
# Epoch 29/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9660 - loss: 0.1061
# Epoch 29: val_accuracy improved from 0.98155 to 0.98357, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 198ms/step - accuracy: 0.9660 - loss: 0.1061 - val_accuracy: 0.9836 - val_loss: 0.0764 - learning_rate: 5.0000e-04
# Epoch 30/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9646 - loss: 0.1066
# Epoch 30: val_accuracy did not improve from 0.98357
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.9646 - loss: 0.1066 - val_accuracy: 0.9823 - val_loss: 0.0683 - learning_rate: 5.0000e-04
# Epoch 31/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9668 - loss: 0.1046
# Epoch 31: val_accuracy did not improve from 0.98357
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 50s 200ms/step - accuracy: 0.9668 - loss: 0.1046 - val_accuracy: 0.9833 - val_loss: 0.0742 - learning_rate: 5.0000e-04
# Epoch 32/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9697 - loss: 0.0977
# Epoch 32: val_accuracy did not improve from 0.98357
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 51s 204ms/step - accuracy: 0.9697 - loss: 0.0977 - val_accuracy: 0.9833 - val_loss: 0.0768 - learning_rate: 5.0000e-04
# Epoch 33/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9682 - loss: 0.1001
# Epoch 33: val_accuracy did not improve from 0.98357
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 197ms/step - accuracy: 0.9682 - loss: 0.1002 - val_accuracy: 0.9810 - val_loss: 0.0785 - learning_rate: 5.0000e-04
# Epoch 34/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9697 - loss: 0.0921
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 34: val_accuracy did not improve from 0.98357
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.9697 - loss: 0.0921 - val_accuracy: 0.9821 - val_loss: 0.0798 - learning_rate: 5.0000e-04
# Epoch 35/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9718 - loss: 0.0897
# Epoch 35: val_accuracy did not improve from 0.98357
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 50s 203ms/step - accuracy: 0.9718 - loss: 0.0897 - val_accuracy: 0.9833 - val_loss: 0.0714 - learning_rate: 2.5000e-04
# Epoch 36/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9722 - loss: 0.0851
# Epoch 36: val_accuracy improved from 0.98357 to 0.98484, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 198ms/step - accuracy: 0.9722 - loss: 0.0851 - val_accuracy: 0.9848 - val_loss: 0.0686 - learning_rate: 2.5000e-04
# Epoch 37/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9749 - loss: 0.0822
# Epoch 37: val_accuracy did not improve from 0.98484
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 198ms/step - accuracy: 0.9749 - loss: 0.0822 - val_accuracy: 0.9848 - val_loss: 0.0697 - learning_rate: 2.5000e-04
# Epoch 38/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9755 - loss: 0.0769
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 38: val_accuracy did not improve from 0.98484
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.9755 - loss: 0.0769 - val_accuracy: 0.9826 - val_loss: 0.0738 - learning_rate: 2.5000e-04
# Epoch 39/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9744 - loss: 0.0792
# Epoch 39: val_accuracy did not improve from 0.98484
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 195ms/step - accuracy: 0.9744 - loss: 0.0792 - val_accuracy: 0.9838 - val_loss: 0.0703 - learning_rate: 1.2500e-04
# Epoch 40/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9736 - loss: 0.0823
# Epoch 40: val_accuracy did not improve from 0.98484
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 48s 194ms/step - accuracy: 0.9736 - loss: 0.0823 - val_accuracy: 0.9836 - val_loss: 0.0775 - learning_rate: 1.2500e-04
# Epoch 41/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9750 - loss: 0.0767
# Epoch 41: val_accuracy did not improve from 0.98484
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 48s 194ms/step - accuracy: 0.9750 - loss: 0.0767 - val_accuracy: 0.9833 - val_loss: 0.0709 - learning_rate: 1.2500e-04
# Epoch 42/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9775 - loss: 0.0726
# Epoch 42: val_accuracy did not improve from 0.98484
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 199ms/step - accuracy: 0.9775 - loss: 0.0726 - val_accuracy: 0.9843 - val_loss: 0.0660 - learning_rate: 1.2500e-04
# Epoch 43/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9726 - loss: 0.0841
# Epoch 43: val_accuracy improved from 0.98484 to 0.98635, saving model to scriptnet_banglalekha_best.h5
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 51s 205ms/step - accuracy: 0.9726 - loss: 0.0840 - val_accuracy: 0.9864 - val_loss: 0.0659 - learning_rate: 1.2500e-04
# Epoch 44/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9756 - loss: 0.0740
# Epoch 44: val_accuracy did not improve from 0.98635
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 51s 206ms/step - accuracy: 0.9755 - loss: 0.0740 - val_accuracy: 0.9846 - val_loss: 0.0702 - learning_rate: 1.2500e-04
# Epoch 45/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9739 - loss: 0.0765
# Epoch 45: val_accuracy did not improve from 0.98635
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 51s 205ms/step - accuracy: 0.9739 - loss: 0.0765 - val_accuracy: 0.9833 - val_loss: 0.0745 - learning_rate: 1.2500e-04
# Epoch 46/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9762 - loss: 0.0740
# Epoch 46: val_accuracy did not improve from 0.98635
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 51s 207ms/step - accuracy: 0.9762 - loss: 0.0740 - val_accuracy: 0.9848 - val_loss: 0.0708 - learning_rate: 1.2500e-04
# Epoch 47/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9763 - loss: 0.0751
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 47: val_accuracy did not improve from 0.98635
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 53s 212ms/step - accuracy: 0.9763 - loss: 0.0751 - val_accuracy: 0.9831 - val_loss: 0.0683 - learning_rate: 1.2500e-04
# Epoch 48/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9743 - loss: 0.0728
# Epoch 48: val_accuracy did not improve from 0.98635
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 51s 205ms/step - accuracy: 0.9743 - loss: 0.0728 - val_accuracy: 0.9828 - val_loss: 0.0702 - learning_rate: 6.2500e-05
# Epoch 49/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9778 - loss: 0.0670
# Epoch 49: val_accuracy did not improve from 0.98635
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 198ms/step - accuracy: 0.9778 - loss: 0.0670 - val_accuracy: 0.9848 - val_loss: 0.0691 - learning_rate: 6.2500e-05
# Epoch 50/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9765 - loss: 0.0724
# Epoch 50: val_accuracy did not improve from 0.98635
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 49s 199ms/step - accuracy: 0.9765 - loss: 0.0724 - val_accuracy: 0.9843 - val_loss: 0.0699 - learning_rate: 6.2500e-05
# Epoch 51/60
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9786 - loss: 0.0681
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 51: val_accuracy did not improve from 0.98635
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 51s 207ms/step - accuracy: 0.9786 - loss: 0.0682 - val_accuracy: 0.9861 - val_loss: 0.0697 - learning_rate: 6.2500e-05

# %%
import matplotlib.pyplot as plt

# Plot Accuracy
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# plot the convergence, in terms of accuracy and loss, of ScriptNet
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Predict labels
y_pred_probs = model.predict(val_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# True labels
y_true = val_generator.classes

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=val_generator.class_indices.keys())
plt.figure(figsize=(12, 12))
disp.plot(cmap='Blues', xticks_rotation=90)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# true and predicted labels
cm = confusion_matrix(y_true, y_pred, labels=range(10))
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(20, 20))
sns.heatmap(cm_normalized, annot=False, cmap='viridis')
plt.title('Normalized Confusion Matrix')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

classes = 10
plt.figure(figsize=(30, 25))  # Bigger figure
sns.heatmap(cm, annot=False, cmap='Blues', cbar=True)
plt.title('Confusion Matrix (84 Classes)')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.xticks(ticks=range(0, classes, 5), labels=range(0, classes, 5), rotation=90)  # Sparse ticks
plt.yticks(ticks=range(0, classes, 5), labels=range(0, classes, 5))
plt.show()

# %%
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

# Predict and true labels (already obtained previously)
y_pred_probs = model.predict(val_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = val_generator.classes
class_names = list(val_generator.class_indices.keys())

# Print classification report
report = classification_report(y_true, y_pred, target_names=class_names, digits=4)
print("📋 Classification Report:\n")
print(report)

# Extract and print macro, weighted scores
precision_macro = precision_score(y_true, y_pred, average='macro')
recall_macro = recall_score(y_true, y_pred, average='macro')
f1_macro = f1_score(y_true, y_pred, average='macro')

precision_weighted = precision_score(y_true, y_pred, average='weighted')
recall_weighted = recall_score(y_true, y_pred, average='weighted')
f1_weighted = f1_score(y_true, y_pred, average='weighted')

print("🔢 Macro Scores")
print(f"Precision (Macro): {precision_macro:.4f}")
print(f"Recall (Macro):    {recall_macro:.4f}")
print(f"F1-score (Macro):  {f1_macro:.4f}")

print("\n🔢 Weighted Scores")
print(f"Precision (Weighted): {precision_weighted:.4f}")
print(f"Recall (Weighted):    {recall_weighted:.4f}")
print(f"F1-score (Weighted):  {f1_weighted:.4f}")
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step
# 📋 Classification Report:
#
#               precision    recall  f1-score   support
#
#           01     0.9823    0.9848    0.9836       395
#           02     0.9898    0.9823    0.9861       396
#           03     0.9798    0.9823    0.9810       395
#           04     0.9823    0.9798    0.9810       396
#           05     0.9723    0.9747    0.9735       396
#           06     0.9746    0.9697    0.9722       396
#           07     0.9949    1.0000    0.9975       394
#           08     0.9801    0.9924    0.9862       397
#           09     0.9949    0.9823    0.9886       396
#           10     0.9899    0.9924    0.9912       396
#
#     accuracy                         0.9841      3957
#    macro avg     0.9841    0.9841    0.9841      3957
# weighted avg     0.9841    0.9841    0.9841      3957
#
# 🔢 Macro Scores
# Precision (Macro): 0.9841
# Recall (Macro):    0.9841
# F1-score (Macro):  0.9841
#
# 🔢 Weighted Scores
# Precision (Weighted): 0.9841
# Recall (Weighted):    0.9841
# F1-score (Weighted):  0.9841
