# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, BatchNormalization,
                                     Activation, Dropout, Flatten, Dense, GlobalAveragePooling2D)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

# ----------------------------
# 1. Model Architecture: ScriptNet
# ----------------------------

def build_scriptnet_lite(input_shape=(64, 64, 1), num_classes=84):
    inputs = Input(shape=input_shape)

    # Block 1
    x = SeparableConv2D(32, (3, 3), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv2D(32, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.25)(x)

    # Block 2
    x = SeparableConv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.3)(x)

    # Block 3
    x = SeparableConv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.4)(x)

    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)

    # Dense
    x = Dense(256)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.5)(x)

    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=inputs, outputs=outputs, name="ScriptNetLite")
    return model
# Out:
# 2025-05-31 15:25:01.751506: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748705101.927807      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748705101.983374      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# ----------------------------
# 2. Data Loading: BanglaLekha-Isolated
# ----------------------------
# Replace this with your full Google Drive path if needed
dataset_path = "/kaggle/input/bangla-lekha-isolated-dataset/BanglaLekha-Isolated/Images/"

input_shape = (64, 64, 1)
batch_size = 64
epochs = 60
num_classes = 84  # Update if using fewer classes

# ImageDataGenerator with augmentation for training and only rescaling for validation
datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    validation_split=0.2,
    rotation_range=15,
    zoom_range=0.15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(64, 64),
    color_mode='grayscale',
    class_mode='sparse',
    batch_size=batch_size,
    subset='training',
    shuffle=True,
    seed=42
)

val_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(64, 64),
    color_mode='grayscale',
    class_mode='sparse',
    batch_size=batch_size,
    subset='validation',
    shuffle=False,
    seed=42
)
# Out:
# Found 132914 images belonging to 84 classes.
# Found 33191 images belonging to 84 classes.

# %%
from tensorflow.keras.layers import SeparableConv2D

# ----------------------------
# 3. Compile Model
# ----------------------------
model = build_scriptnet_lite(input_shape=input_shape, num_classes=num_classes)
model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# I0000 00:00:1748705170.855648      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1748705170.856317      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "ScriptNetLite"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 64, 64, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ separable_conv2d (SeparableConv2D)   │ (None, 64, 64, 32)          │              73 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 64, 64, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ separable_conv2d_1 (SeparableConv2D) │ (None, 64, 64, 32)          │           1,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64, 64, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ separable_conv2d_2 (SeparableConv2D) │ (None, 32, 32, 64)          │           2,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ separable_conv2d_3 (SeparableConv2D) │ (None, 32, 32, 64)          │           4,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ separable_conv2d_4 (SeparableConv2D) │ (None, 16, 16, 128)         │           8,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ separable_conv2d_5 (SeparableConv2D) │ (None, 16, 16, 128)         │          17,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 84)                  │          21,588 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 92,541 (361.49 KB)
#  Trainable params: 91,133 (355.99 KB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
# ----------------------------
# 4. Callbacks
# ----------------------------
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, verbose=1),
    EarlyStopping(monitor='val_accuracy', patience=7, min_delta=0.001, restore_best_weights=True),
    ModelCheckpoint("scriptnet_banglalekha_best.h5", monitor="val_accuracy", save_best_only=True, verbose=1)
]

epochs=100

# ----------------------------
# 5. Train Model
# ----------------------------
steps_per_epoch = np.ceil(train_generator.samples / batch_size).astype(int)
validation_steps = np.ceil(val_generator.samples / batch_size).astype(int)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748705180.784176     111 service.cc:148] XLA service 0x2b8fd580 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748705180.785179     111 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1748705180.785205     111 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1748705181.612654     111 cuda_dnn.cc:529] Loaded cuDNN version 90300
#    1/2077 ━━━━━━━━━━━━━━━━━━━━ 10:00:53 17s/step - accuracy: 0.0312 - loss: 5.1466
# I0000 00:00:1748705189.994763     111 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.0458 - loss: 4.2732
# Epoch 1: val_accuracy improved from -inf to 0.23931, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 667s 313ms/step - accuracy: 0.0458 - loss: 4.2729 - val_accuracy: 0.2393 - val_loss: 2.8530 - learning_rate: 0.0010
# Epoch 2/100
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.2596 - loss: 2.7164
# Epoch 2: val_accuracy improved from 0.23931 to 0.58055, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 528s 254ms/step - accuracy: 0.2596 - loss: 2.7163 - val_accuracy: 0.5805 - val_loss: 1.5132 - learning_rate: 0.0010
# Epoch 3/100
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.4319 - loss: 2.0136
# Epoch 3: val_accuracy improved from 0.58055 to 0.72779, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 395s 190ms/step - accuracy: 0.4319 - loss: 2.0136 - val_accuracy: 0.7278 - val_loss: 0.9422 - learning_rate: 0.0010
# Epoch 4/100
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5022 - loss: 1.7627
# Epoch 4: val_accuracy improved from 0.72779 to 0.80814, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 424s 204ms/step - accuracy: 0.5023 - loss: 1.7627 - val_accuracy: 0.8081 - val_loss: 0.7077 - learning_rate: 0.0010
# Epoch 5/100
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5458 - loss: 1.6098
# Epoch 5: val_accuracy did not improve from 0.80814
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 389s 187ms/step - accuracy: 0.5458 - loss: 1.6098 - val_accuracy: 0.7988 - val_loss: 0.7072 - learning_rate: 0.0010
# Epoch 6/100
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.5668 - loss: 1.5401
# Epoch 6: val_accuracy improved from 0.80814 to 0.83610, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 377s 181ms/step - accuracy: 0.5669 - loss: 1.5401 - val_accuracy: 0.8361 - val_loss: 0.5834 - learning_rate: 0.0010
# Epoch 7/100
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5861 - loss: 1.4790
# Epoch 7: val_accuracy did not improve from 0.83610
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 384s 185ms/step - accuracy: 0.5861 - loss: 1.4790 - val_accuracy: 0.8253 - val_loss: 0.6309 - learning_rate: 0.0010
# Epoch 8/100
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.6013 - loss: 1.4197
# Epoch 8: val_accuracy did not improve from 0.83610
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 364s 175ms/step - accuracy: 0.6013 - loss: 1.4197 - val_accuracy: 0.8111 - val_loss: 0.6658 - learning_rate: 0.0010
# Epoch 9/100
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6112 - loss: 1.3940
# Epoch 9: val_accuracy improved from 0.83610 to 0.85162, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 372s 179ms/step - accuracy: 0.6112 - loss: 1.3940 - val_accuracy: 0.8516 - val_loss: 0.5448 - learning_rate: 0.0010
# Epoch 10/100
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.6209 - loss: 1.3571
# Epoch 10: val_accuracy did not improve from 0.85162
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 387s 186ms/step - accuracy: 0.6209 - loss: 1.3571 - val_accuracy: 0.4993 - val_loss: 2.1546 - learning_rate: 0.0010
# Epoch 11/100
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.6307 - loss: 1.3211
# Epoch 11: val_accuracy improved from 0.85162 to 0.87228, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 445s 214ms/step - accuracy: 0.6307 - loss: 1.3211 - val_accuracy: 0.8723 - val_loss: 0.4650 - learning_rate: 0.0010
# Epoch 12/100
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6366 - loss: 1.3039
# Epoch 12: val_accuracy did not improve from 0.87228
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 391s 188ms/step - accuracy: 0.6366 - loss: 1.3039 - val_accuracy: 0.3993 - val_loss: 3.1625 - learning_rate: 0.0010
# Epoch 13/100
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6406 - loss: 1.2897
# Epoch 13: val_accuracy improved from 0.87228 to 0.88542, saving model to scriptnet_banglalekha_best.h5
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 414s 199ms/step - accuracy: 0.6406 - loss: 1.2897 - val_accuracy: 0.8854 - val_loss: 0.4182 - learning_rate: 0.0010
# Epoch 14/100
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6502 - loss: 1.2583
# Epoch 14: val_accuracy did not improve from 0.88542
# 2077/2077 ━━━━━━━━━━━━━━━━━━━━ 427s 206ms/step - accuracy: 0.6502 - loss: 1.2583 - val_accuracy: 0.4198 - val_loss: 2.8476 - learning_rate: 0.0010
# Epoch 15/100
# 1669/2077 ━━━━━━━━━━━━━━━━━━━━ 1:07 166ms/step - accuracy: 0.6526 - loss: 1.2459

# %%
print("Done")
